# %% [markdown]
# <a href="https://colab.research.google.com/github/Thiru-23/Project/blob/main/Waterpotabilityfinal_pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact

# %%
 from google.colab import files
uploaded=files.upload()


data=pd.read_csv("/content/Water.csv")
# Out:
#      <input type="file" id="files-cfe10d54-1e81-4474-a2a5-6b0f0c8c449f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfe10d54-1e81-4474-a2a5-6b0f0c8c449f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()
data.head(5)
# Out:
#          ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.05786     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.54173     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436525       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
data.shape
# Out:
# (200, 10)

# %%
data.isnull().sum()
# Out:
# ph                 30
# Hardness            0
# Solids              0
# Chloramines         0
# Sulfate            56
# Conductivity        0
# Organic_carbon      0
# Trihalomethanes     6
# Turbidity           0
# Potability          0
# dtype: int64

# %%
data.describe()
# Out:
#                ph    Hardness        Solids  Chloramines     Sulfate  \
# count  170.000000  200.000000    200.000000   200.000000  144.000000
# mean     7.121406  196.221950  23002.204430     7.028571  332.011268
# std      1.793141   43.302090   9054.713915     1.389148   33.775192
# min      1.844538   94.812545   2835.303165     3.458192  247.200826
# 25%      5.911344  172.512936  16643.801752     6.108230  307.746285
# 50%      7.006245  198.605573  22316.229730     7.012144  329.032633
# 75%      8.459174  223.434409  28628.438005     7.902204  355.630293
# max     11.491011  304.235912  51731.820550    10.558950  404.041635
#
#        Conductivity  Organic_carbon  Trihalomethanes   Turbidity  Potability
# count    200.000000      200.000000       194.000000  200.000000   200.00000
# mean     431.019678       13.927416        64.233543    3.978666     0.50500
# std       82.874750        3.346240        16.306956    0.797561     0.50123
# ...

# %%
data.shape
# Out:
# (200, 10)

# %%
data.info
# Out:
# <bound method DataFrame.info of            ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0         NaN  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1    3.716080  129.422921  18630.05786     6.635246         NaN    592.885359
# 2    8.099124  224.236259  19909.54173     9.275884         NaN    418.606213
# 3    8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4    9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# ..        ...         ...          ...          ...         ...           ...
# 195  4.668102  193.681736  47580.99160     7.166639  359.948574    526.424171
# 196  7.808856  193.553212  17329.80216     8.061362         NaN    392.449580
# 197  9.419510  175.762646  33155.57822     7.350233         NaN    432.044783
# 198  5.126763  230.603758  11983.86938     6.303357         NaN    402.883113
# 199  7.874671  195.102299  17404.17706     7.509306         NaN    327.459761
#
# ...

# %%
data.fillna(data.mean(),inplace=True)

# %%
data.head(4)
# Out:
#          ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.121406  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.05786     6.635246  332.011268    592.885359
# 2  8.099124  224.236259  19909.54173     9.275884  332.011268    418.606213
# 3  8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436525       100.341674   4.628771           0

# %%
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
data.head(3)
# Out:
#          ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.121406  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.05786     6.635246  332.011268    592.885359
# 2  8.099124  224.236259  19909.54173     9.275884  332.011268    418.606213
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0

# %%
df=pd.DataFrame(data)

# %%
data.insert(10,"result",0)

# %%
data.loc[data["Potability"]==0,"result"]= "Notdrinkable"
data.loc[data["Potability"]==1,"result"]="Drinkable"
# Out:
# <ipython-input-21-6094f67175e7>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Notdrinkable' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[data["Potability"]==0,"result"]= "Notdrinkable"

# %%
data.head(20)
# Out:
#            ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0    7.121406  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1    3.716080  129.422921  18630.05786     6.635246  332.011268    592.885359
# 2    8.099124  224.236259  19909.54173     9.275884  332.011268    418.606213
# 3    8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4    9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 5    5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 6   10.223862  248.071735  28749.71654     7.513408  393.663395    283.651634
# 7    8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
# 8    7.121406  118.988579  14285.58385     7.804174  268.646941    389.375566
# 9   11.180284  227.231469  25484.50849     9.077200  404.041635    563.885481
# 10   7.360640  165.520797  32452.61441     7.550701  326.624353    425.383420
# ...

# %%
data["ph"]=round(data["ph"])
data["Hardness"]=round(data["Hardness"])
data["Solids"]=round(data["Solids"])
data["Chloramines"]=round(data["Chloramines"])
data["Sulfate"]=round(data["Sulfate"])
data["Conductivity"]=round(data["Conductivity"])
data["Organic_carbon"]=round(data["Organic_carbon"])
data["Trihalomethanes"]=round(data["Trihalomethanes"])
data["Turbidity"]=round(data["Turbidity"])

# %%
data["ph"]
# Out:
# 0      7.0
# 1      4.0
# 2      8.0
# 3      8.0
# 4      9.0
#       ...
# 195    5.0
# 196    8.0
# 197    9.0
# 198    5.0
# 199    8.0
# Name: ph, Length: 200, dtype: float64

# %%
data.tail(1555)
# Out:
#       ph  Hardness   Solids  Chloramines  Sulfate  Conductivity  \
# 0    7.0     205.0  20791.0          7.0    369.0         564.0
# 1    4.0     129.0  18630.0          7.0    332.0         593.0
# 2    8.0     224.0  19910.0          9.0    332.0         419.0
# 3    8.0     214.0  22018.0          8.0    357.0         363.0
# 4    9.0     181.0  17979.0          7.0    310.0         398.0
# ..   ...       ...      ...          ...      ...           ...
# 195  5.0     194.0  47581.0          7.0    360.0         526.0
# 196  8.0     194.0  17330.0          8.0    332.0         392.0
# 197  9.0     176.0  33156.0          7.0    332.0         432.0
# 198  5.0     231.0  11984.0          6.0    332.0         403.0
# 199  8.0     195.0  17404.0          8.0    332.0         327.0
#
#      Organic_carbon  Trihalomethanes  Turbidity  Potability        result
# 0              10.0             87.0        3.0           0  Notdrinkable
# ...

# %%
data.pop("Potability")
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: Potability, Length: 200, dtype: int64

# %%
data.head(9)
# Out:
#      ph  Hardness   Solids  Chloramines  Sulfate  Conductivity  \
# 0   7.0     205.0  20791.0          7.0    369.0         564.0
# 1   4.0     129.0  18630.0          7.0    332.0         593.0
# 2   8.0     224.0  19910.0          9.0    332.0         419.0
# 3   8.0     214.0  22018.0          8.0    357.0         363.0
# 4   9.0     181.0  17979.0          7.0    310.0         398.0
# 5   6.0     188.0  28749.0          8.0    327.0         280.0
# 6  10.0     248.0  28750.0          8.0    394.0         284.0
# 7   9.0     203.0  13672.0          5.0    303.0         475.0
# 8   7.0     119.0  14286.0          8.0    269.0         389.0
#
#    Organic_carbon  Trihalomethanes  Turbidity        result
# 0            10.0             87.0        3.0  Notdrinkable
# 1            15.0             56.0        5.0  Notdrinkable
# 2            17.0             66.0        3.0  Notdrinkable
# 3            18.0            100.0        5.0  Notdrinkable
# ...

# %%
data["result"].value_counts()
# Out:
# result
# Drinkable       101
# Notdrinkable     99
# Name: count, dtype: int64

# %%
data['ph'].mean()
# Out:
# 7.105

# %%
data["Hardness"].mean()
# Out:
# 196.21

# %%
data["Solids"].mean()
# Out:
# 23002.22

# %%
data["Chloramines"].mean()
# Out:
# 7.045

# %%
data["Sulfate"].mean()
# Out:
# 332.02

# %%
data["Conductivity"].mean()
# Out:
# 431.0

# %%
data["Organic_carbon"].mean()
# Out:
# 13.925

# %%
data["Trihalomethanes"].mean()
# Out:
# 64.23

# %%
data["Turbidity"].mean()
# Out:
# 3.95

# %%
y=data["result"]
x=data.drop(["result"],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 9)
# (40, 9)
# (160,)
# (40,)

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
prediction=model.predict((np.array([[23,45,78,11,678,55,33,76,98]])))
print(prediction)
# Out:
# ['Notdrinkable']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict((np.array([[7.1,196.7,23332.7,7.07,332.7,429.7,14,63.6,3.9]])))
print(prediction)
# Out:
# ['Drinkable']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict((np.array([[7,196,23332,7,332,429,14,63,3]])))
print(prediction)
# Out:
# ['Drinkable']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict((np.array([[7,1.7,23332.7,7.07,332.7,429.7,14,63.6,3.9]])))
print(prediction)
# Out:
# ['Notdrinkable']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
